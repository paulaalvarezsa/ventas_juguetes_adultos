# %%
import pandas as pd
import numpy as np
import re

# %%
m = pd.read_csv('df_melted_2.csv')
m
# Out:
#         Column Name       Value
# 0        b'NewMoon'  2022-01-02
# 1        b'NewMoon'  2022-02-01
# 2        b'NewMoon'  2022-03-02
# 3        b'NewMoon'  2022-04-01
# 4        b'NewMoon'  2022-04-30
# 5        b'NewMoon'  2022-05-30
# 6        b'NewMoon'  2022-06-29
# 7        b'NewMoon'  2022-07-28
# 8        b'NewMoon'  2022-08-27
# 9        b'NewMoon'  2022-09-25
# 10       b'NewMoon'  2022-10-25
# 11       b'NewMoon'  2022-11-23
# 12       b'NewMoon'  2022-12-23
# 13  b'FirstQuarter'  2022-01-09
# 14  b'FirstQuarter'  2022-02-08
# 15  b'FirstQuarter'  2022-03-10
# 16  b'FirstQuarter'  2022-04-09
# 17  b'FirstQuarter'  2022-05-09
# 18  b'FirstQuarter'  2022-06-07
# 19  b'FirstQuarter'  2022-07-07
# 20  b'FirstQuarter'  2022-08-05
# 21  b'FirstQuarter'  2022-09-03
# 22  b'FirstQuarter'  2022-10-03
# 23  b'FirstQuarter'  2022-11-01
# 24  b'FirstQuarter'  2022-11-30
# 25  b'FirstQuarter'  2022-12-30
# 26      b'FullMoon'  2022-01-18
# 27      b'FullMoon'  2022-02-16
# ...

# %%
o = pd.read_csv('oil_clean.csv')

# %%
o
# Out:
#           Fecha Último
# 0    2022-12-30  85,91
# 1    2022-12-29  82,26
# 2    2022-12-28  83,26
# 3    2022-12-27  84,68
# 4    2022-12-23  84,50
# ..          ...    ...
# 248  2022-01-14  86,06
# 249  2022-01-13  84,47
# 250  2022-01-12  84,67
# 251  2022-01-11  83,72
# 252  2022-01-10  80,87
#
# [253 rows x 2 columns]

# %%
s = pd.read_csv('sales_clean.csv')
s
# Out:
#          Diario Da de la Semana        Mes  Pedidos Facturacin Ingreso neto  \
# 0    2022-01-01           sbado      enero       62   3.240,86     2.650,79
# 1    2022-02-01          domingo      enero       99   5.665,29     4.727,17
# 2    2022-03-01            lunes      enero      165   8.575,63     7.037,96
# 3    2022-04-01           martes      enero      125   5.925,75     4.882,08
# 4    2022-05-01        mircoles      enero       96   5.430,73     4.512,06
# ..          ...              ...        ...      ...         ...          ...
# 360  2022-12-27           martes  diciembre       44   2.425,11     2.017,84
# 361  2022-12-28        mircoles  diciembre       35   1.798,95     1.506,94
# 362  2022-12-29           jueves  diciembre       28   1.403,10     1.161,39
# 363  2022-12-30          viernes  diciembre       32   2.412,47     2.019,46
# 364  2022-12-31           sbado  diciembre       12     977,00       815,81
#
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///data.db')

# %%
s.to_sql('sales_sql_2', engine)
# Out:
# 365

# %%
m.to_sql('moom_sql', engine)
o.to_sql('oil_sql', engine)
# Out:
# 253

# %%
import dataclasses

# %%
# Out:
#   Cell In[16], line 1
#     sqlite3 data.db
#             ^
# SyntaxError: invalid syntax
